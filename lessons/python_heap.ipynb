# %% [markdown]
# By the end of these lesson modules you should be able to :
#
# -Find Top K Numbers
# -Find Kth Smaller Number
# -Find K Closest Points to Origin
# -Find Minimum Cost to Connect Ropes
# -Order Agnostic Binary Search
