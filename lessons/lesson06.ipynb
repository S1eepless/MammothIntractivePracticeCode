# %% [markdown]
# Mammoth interview question
# Is Linked List Cycle
#
# -Must determine if a linked list has a cycle
# if it does, return true
# if it doesn't, return false

# %%
class Node:
    def __init__(self, value, next=None):
        self.value = value
        self.next = next
    
def has_cycle(head):

    slow, fast = head, head

    while fast is not None and fast.next is not None:   #as long as fast has a value the code will continue to run

        fast = fast.next.next   #checks ahead of the next node
        slow = slow.next
        if slow == fast:        #
            return True

    return False

head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)
head.next.next.next.next = Node(5)
head.next.next.next.next.next = head.next.next #this line transforms the linked list into a cycle

has_cycle(head)
print(has_cycle(head))
# Out:
# True
